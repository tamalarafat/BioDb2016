# %%
def REVC(x):
    y = ''
    for i in x:
        if i == 'T':
            y = y+'A'
        elif i == 'A':
            y = y + 'T'
        elif i == 'C':
            y = y + 'G'
        elif i == 'G':
            y = y + 'C'
    return y[::-1]

b = '...'
REVC(b)
